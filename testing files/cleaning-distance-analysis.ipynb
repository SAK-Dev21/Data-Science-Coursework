# %% [markdown]
# # Setting up files

# %%
import pandas as pd

# %%
tripsByDistanceDF = pd.read_csv('../datasets/Trips_by_Distance (1).csv')

# %% [markdown]
# # Examining the dataset

# %%
tripsByDistanceDF
# Out:
#          Level        Date  State FIPS State Postal Code  County FIPS  \
# 0       County  2021-06-06        56.0                WY      56045.0
# 1       County  2021-06-06         5.0                AR       5011.0
# 2       County  2021-06-06         5.0                AR       5013.0
# 3       County  2021-06-06         5.0                AR       5015.0
# 4       County  2021-06-06         5.0                AR       5017.0
# ...        ...         ...         ...               ...          ...
# 988768  County  2019-11-01        19.0                IA      19185.0
# 988769  County  2019-11-01        19.0                IA      19187.0
# 988770  County  2019-11-01        19.0                IA      19189.0
# 988771  County  2019-11-01        19.0                IA      19191.0
# 988772  County  2019-11-01        19.0                IA      19193.0
#
#               County Name  Population Staying at Home  \
# 0           Weston County                        1268
# ...

# %% [markdown]
# ## Checking dataset information

# %%
tripsByDistanceDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988773 entries, 0 to 988772
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Level                           988773 non-null  object
#  1   Date                            988773 non-null  object
#  2   State FIPS                      988773 non-null  float64
#  3   State Postal Code               988773 non-null  object
#  4   County FIPS                     988773 non-null  float64
#  5   County Name                     988773 non-null  object
#  6   Population Staying at Home      988773 non-null  int64
#  7   Population Not Staying at Home  988773 non-null  int64
#  8   Number of Trips                 988773 non-null  int64
#  9   Number of Trips <1              988773 non-null  int64
#  10  Number of Trips 1-3             988773 non-null  int64
#  11  Number of Trips 3-5             988773 non-null  int64
# ...

# %% [markdown]
# ## Checking for missing values

# %%
tripsByDistanceDF.isnull().sum()
# Out:
# Level                             0
# Date                              0
# State FIPS                        0
# State Postal Code                 0
# County FIPS                       0
# County Name                       0
# Population Staying at Home        0
# Population Not Staying at Home    0
# Number of Trips                   0
# Number of Trips <1                0
# Number of Trips 1-3               0
# Number of Trips 3-5               0
# Number of Trips 5-10              0
# Number of Trips 10-25             0
# Number of Trips 25-50             0
# Number of Trips 50-100            0
# Number of Trips 100-250           0
# Number of Trips 250-500           0
# Number of Trips >=500             0
# Row ID                            0
# Week                              0
# Month                             0
# dtype: int64

# %% [markdown]
# # Checking for duplicates
#
# * There are no duplicate rows so no work will be done to remove any duplicate rows.

# %%
tripsByDistanceDF.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Handling missing values & Correcting values and columns

# %% [markdown]
# ## Dropping all rows that have missing values

# %%
tripsByDistanceDF.dropna(inplace = True)

# %% [markdown]
# ## Correcting columns with incorrect data type
#
# * Date: Datetime instead of object.
# * All 'number of ___' and 'Population' columns should be int instead of float.

# %%
tripsByDistanceDF['Date'] = pd.to_datetime(tripsByDistanceDF['Date'], errors = 'coerce')

# %% [markdown]
# - This code is already executed and cannot be executed again otherwise there will be an error.

# %%
numberOfColumns = ['Number of Trips', 'Number of Trips <1', 'Number of Trips 1-3', 'Number of Trips 3-5', 
                   'Number of Trips 5-10',
                   'Number of Trips 10-25',
                   'Number of Trips 25-50',
                   'Number of Trips 50-100',
                   'Number of Trips 100-250',
                   'Number of Trips 250-500',
                   'Number of Trips >=500']

tripsByDistanceDF[numberOfColumns] = tripsByDistanceDF[numberOfColumns].astype(int)

# %% [markdown]
# I forgot to add the population columns in the big list so i am changing those columns to be int data type here.

# %%
populationColumns = ['Population Staying at Home',
                   'Population Not Staying at Home']

tripsByDistanceDF[populationColumns] = tripsByDistanceDF[populationColumns].astype(int)

# %%
tripsByDistanceDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988773 entries, 0 to 988772
# Data columns (total 22 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Level                           988773 non-null  object
#  1   Date                            988773 non-null  datetime64[ns]
#  2   State FIPS                      988773 non-null  float64
#  3   State Postal Code               988773 non-null  object
#  4   County FIPS                     988773 non-null  float64
#  5   County Name                     988773 non-null  object
#  6   Population Staying at Home      988773 non-null  int64
#  7   Population Not Staying at Home  988773 non-null  int64
#  8   Number of Trips                 988773 non-null  int64
#  9   Number of Trips <1              988773 non-null  int64
#  10  Number of Trips 1-3             988773 non-null  int64
# ...

# %% [markdown]
# ## Saving cleaned dataset

# %%
tripsByDistanceDF.to_csv('../datasets/cleaned-datasets/Trips_by_Distance-cleaned.csv', index = False)
